# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Creating of the CSV file
po=pd.read_csv('pokemon.csv')
po.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
po.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
po['Attack'].value_counts()
# Out:
# 100    40
# 65     39
# 50     37
# 80     37
# 85     33
#        ..
# 46      1
# 190     1
# 106     1
# 132     1
# 33      1
# Name: Attack, Length: 111, dtype: int64

# %% [markdown]
# ### How many pokemenon have the attack greater than 150

# %%
sns.boxplot(x='Attack',data=po)
# Out:
# <AxesSubplot:xlabel='Attack'>

# %%
po.loc[po['Attack']>150]
# Out:
#        #                     Name   Type 1    Type 2  Total   HP  Attack  \
# 137  127        PinsirMega Pinsir      Bug    Flying    600   65     155
# 141  130    GyaradosMega Gyarados    Water      Dark    640   95     155
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 232  214  HeracrossMega Heracross      Bug  Fighting    600   80     185
# 268  248  TyranitarMega Tyranitar     Rock      Dark    700  100     164
# 279  257    BlazikenMega Blaziken     Fire  Fighting    630   80     160
# 313  289                  Slaking   Normal       NaN    670  150     160
# 387  354      BanetteMega Banette    Ghost       NaN    555   64     165
# 424  383    GroudonPrimal Groudon   Ground      Fire    770  100     180
# 426  384    RayquazaMega Rayquaza   Dragon    Flying    780  105     180
# 429  386       DeoxysAttack Forme  Psychic       NaN    600   50     180
# 454  409                Rampardos     Rock       NaN    495   97     165
# ...

# %%
po.loc[po['Attack']>150].shape
# Out:
# (18, 13)

# %%
po.loc[po['Attack']>150].head(5)
# Out:
#        #                     Name   Type 1    Type 2  Total   HP  Attack  \
# 137  127        PinsirMega Pinsir      Bug    Flying    600   65     155
# 141  130    GyaradosMega Gyarados    Water      Dark    640   95     155
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 232  214  HeracrossMega Heracross      Bug  Fighting    600   80     185
# 268  248  TyranitarMega Tyranitar     Rock      Dark    700  100     164
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 137      120       65       90    105           1      False
# 141      109       70      130     81           1      False
# 163      100      154      100    130           1       True
# 232      115       40      105     75           2      False
# 268      150       95      120     71           2      False

# %%
po['Speed'].value_counts()
# Out:
# 50     46
# 60     44
# 70     37
# 65     36
# 30     35
#        ..
# 39      1
# 24      1
# 82      1
# 113     1
# 123     1
# Name: Speed, Length: 108, dtype: int64

# %% [markdown]
# ### How many pokemons have the speed less than equal to 10

# %%
sns.boxplot(x='Speed',data=po)
plt.show()

# %%
po.loc[po['Speed']<=10].shape
# Out:
# (5, 13)

# %%
po.loc[po['Speed']<=10].head()
# Out:
#        #       Name  Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 230  213    Shuckle     Bug   Rock    505   20      10      230       10
# 359  328   Trapinch  Ground    NaN    290   45     100       45       45
# 486  438     Bonsly    Rock    NaN    290   50      80       95       10
# 495  446   Munchlax  Normal    NaN    390  135      85       40       40
# 658  597  Ferroseed   Grass  Steel    305   44      50       91       24
#
#      Sp. Def  Speed  Generation  Legendary
# 230      230      5           2      False
# 359       45     10           3      False
# 486       45     10           4      False
# 495       85      5           4      False
# 658       86     10           5      False

# %%
po.query("Speed<=10").head(3)
# Out:
#        #      Name  Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 230  213   Shuckle     Bug   Rock    505  20      10      230       10
# 359  328  Trapinch  Ground    NaN    290  45     100       45       45
# 486  438    Bonsly    Rock    NaN    290  50      80       95       10
#
#      Sp. Def  Speed  Generation  Legendary
# 230      230      5           2      False
# 359       45     10           3      False
# 486       45     10           4      False

# %% [markdown]
# ### How many pokemons have the sp Def less than 25

# %%
po.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
po.loc[po['Sp. Def']<=25].shape
# Out:
# (18, 13)

# %%
import warnings
warnings.filterwarnings('ignore')
po.loc[po['Sp. Def']<=25].shape
# Out:
# (18, 13)

# %%
(po['Sp. Def']<=25).sum()  #for checking the sum
# Out:
# 18

# %% [markdown]
# ### Hnadling with bool datatype

# %%
po.loc[po['Legendary']].shape #This will return the true value shape
# Out:
# (65, 13)

# %%
po.loc[po['Legendary']==False].shape #This will return the false value shape
# Out:
# (735, 13)

# %%
plt.figure(figsize=(10,5))
ax=sns.scatterplot(data=po,x='Defense', y='Attack')
ax.annotate("What plot is saying",xy=(228,10),xytext=(150,10),
    arrowprops=dict(arrowstyle='->',color='Red'))
plt.show()

# %% [markdown]
# ### Display the record that sort the value of Defense in false Ascending and attack in true Ascending

# %%
po.sort_values(by=['Defense'],ascending=False)
# Out:
#        #                 Name    Type 1  Type 2  Total   HP  Attack  Defense  \
# 230  213              Shuckle       Bug    Rock    505   20      10      230
# 224  208  SteelixMega Steelix     Steel  Ground    610   75     125      230
# 333  306    AggronMega Aggron     Steel     NaN    630   70     140      230
# 223  208              Steelix     Steel  Ground    510   75      85      200
# 414  377             Regirock      Rock     NaN    580   80     100      200
# ..   ...                  ...       ...     ...    ...  ...     ...      ...
# 68    63                 Abra   Psychic     NaN    310   25      20       15
# 186  172                Pichu  Electric     NaN    205   20      40       15
# 261  242              Blissey    Normal     NaN    540  255      10       10
# 488  440              Happiny    Normal     NaN    220  100       5        5
# 121  113              Chansey    Normal     NaN    450  250       5        5
#
# ...

# %%
po.sort_values(by=['Defense','Attack'],ascending=[False,True]).head()
# Out:
#        #                 Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 230  213              Shuckle    Bug    Rock    505  20      10      230
# 224  208  SteelixMega Steelix  Steel  Ground    610  75     125      230
# 333  306    AggronMega Aggron  Steel     NaN    630  70     140      230
# 223  208              Steelix  Steel  Ground    510  75      85      200
# 414  377             Regirock   Rock     NaN    580  80     100      200
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 230       10      230      5           2      False
# 224       55       95     30           2      False
# 333       60       80     50           3      False
# 223       55       65     30           2      False
# 414       50      100     50           3       True

# %%
po['Type 1'].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
po['Type 2'].value_counts()
# Out:
# Flying      97
# Ground      35
# Poison      34
# Psychic     33
# Fighting    26
# Grass       25
# Fairy       23
# Steel       22
# Dark        20
# Dragon      18
# Water       14
# Ghost       14
# Ice         14
# Rock        14
# Fire        12
# Electric     6
# Normal       4
# Bug          3
# Name: Type 2, dtype: int64

# %% [markdown]
# ### How many pokemons are type 1 fire and type 2 flying

# %%
(po['Type 1']=='Fire').sum()
# Out:
# 52

# %%
(po['Type 2']=='Flying').sum()
# Out:
# 97

# %% [markdown]
# ### how many pokemons are type 1 fire and type 2 flying together

# %%
(
  (po['Type 1']=='Fire')&
   (po['Type 2']=='Flying')
).sum()
# Out:
# 6

# %% [markdown]
# ### for checking the complete record of both type 1 fire and type 2 flying

# %%
po.loc[
  (po['Type 1']=='Fire')&
   (po['Type 2']=='Flying')
].head()
# Out:
#        #                       Name Type 1  Type 2  Total   HP  Attack  \
# 6      6                  Charizard   Fire  Flying    534   78      84
# 8      6  CharizardMega Charizard Y   Fire  Flying    634   78     104
# 158  146                    Moltres   Fire  Flying    580   90     100
# 270  250                      Ho-oh   Fire  Flying    680  106     130
# 730  662                Fletchinder   Fire  Flying    382   62      73
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 6         78      109       85    100           1      False
# 8         78      159      115    100           1      False
# 158       90      125       85     90           1       True
# 270       90      110      154     90           2       True
# 730       55       56       52     84           6      False

# %% [markdown]
# ### How many poision pokemon are across both types

# %%
po.query(" `Type 1`=='Poison' or `Type 2`=='Poison' ").shape
# Out:
# (62, 13)

# %% [markdown]
# ### Display the record having the type1 as ice and defense max

# %%
po.loc[po['Type 1']=='Ice','Defense'].max()
# Out:
# 184

# %%
po.loc[
    (po['Type 1']=='Ice')&
    (po['Defense']==po.loc[po['Type 1']=='Ice','Defense'].max())
]
# Out:
#        #     Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 789  713  Avalugg    Ice    NaN    514  95     117      184       44       46
#
#      Speed  Generation  Legendary
# 789     28           6      False

# %%
po.loc[po['Type 1']=='Poison'].head()
# Out:
#      #       Name  Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 28  23      Ekans  Poison     NaN    288  35      60       44       40
# 29  24      Arbok  Poison     NaN    438  60      85       69       65
# 34  29   Nidoran♀  Poison     NaN    275  55      47       52       40
# 35  30   Nidorina  Poison     NaN    365  70      62       67       55
# 36  31  Nidoqueen  Poison  Ground    505  90      92       87       75
#
#     Sp. Def  Speed  Generation  Legendary
# 28       54     55           1      False
# 29       79     80           1      False
# 34       40     41           1      False
# 35       55     56           1      False
# 36       85     76           1      False

# %%
po['Generation'].value_counts()
# Out:
# 1    166
# 5    165
# 3    160
# 4    121
# 2    106
# 6     82
# Name: Generation, dtype: int64

# %% [markdown]
# ### What is the most common type of legendary pokemon?

# %%
po[["Legendary"],'Type 1'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(['Legendary'], 'Type 1')' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7604\3558594038.py in <module>
# ----> 1 po[["Legendary"],'Type 1'].value_counts()
#
# ...

# %%
po['Generation'].value_counts(sort=False).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
(
    (po['Generation']==1)|
    (po['Generation']==2)|
    (po['Generation']==3)
).sum()
# Out:
# 432

# %%
po['Generation'].isin([1,2,3]).sum()
# Out:
# 432

# %%
po.loc[
    (po['Type 1']=='Water')&
    po['Generation'].isin([1,2,3])
].sort_values(by='Total',ascending)

# %%
po.loc[
    (po['Type 1']=='Dragon')|
    (po['Type 2']=='Dragon')&
    (po['Generation'].isin({5,6}))
].sort_values(by='Total',ascending=False).head()
# Out:
#        #                     Name  Type 1  Type 2  Total   HP  Attack  \
# 426  384    RayquazaMega Rayquaza  Dragon  Flying    780  105     180
# 711  646       KyuremBlack Kyurem  Dragon     Ice    700  125     170
# 494  445    GarchompMega Garchomp  Dragon  Ground    700  108     170
# 409  373  SalamenceMega Salamence  Dragon  Flying    700   95     145
# 712  646       KyuremWhite Kyurem  Dragon     Ice    700  125     120
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 426      100      180      100    115           3       True
# 711      100      120       90     95           5       True
# 494      115      120       95     92           4      False
# 409      130      120       90    120           3      False
# 712       90      170      100     95           5       True
