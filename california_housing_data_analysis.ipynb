# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import fetch_california_housing

# %%
house=fetch_california_housing()

# %%
house.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'feature_names', 'DESCR'])

# %%
house.data
# Out:
# array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#           39.37      , -121.24      ]])

# %%
house.feature_names
# Out:
# ['MedInc',
#  'HouseAge',
#  'AveRooms',
#  'AveBedrms',
#  'Population',
#  'AveOccup',
#  'Latitude',
#  'Longitude']

# %%
house.target_names
# Out:
# ['MedHouseVal']

# %%
cf=pd.DataFrame(data=house.data, columns=house.feature_names)

# %%
cf.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
cf['Price']=house.target

# %%
cf.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  Price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %%
x=cf.drop('Price',axis=1)
y=cf['Price']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.2,
                                   random_state=42)

# %%
X_train.shape,X_test.shape,Y_train.shape,Y_test.shape
# Out:
# ((16512, 8), (4128, 8), (16512,), (4128,))

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
df = pd.DataFrame(data=house.data, columns=house.feature_names)

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
df.columns
# Out:
# Index(['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
#        'Latitude', 'Longitude'],
#       dtype='object')

# %%
cormat=cf.corr()
cormat
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge   -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms    0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms  -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population  0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup    0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude   -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude  -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# Price       0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#             Latitude  Longitude     Price
# MedInc     -0.079809  -0.015176  0.688075
# HouseAge    0.011173  -0.108197  0.105623
# AveRooms    0.106389  -0.027540  0.151948
# AveBedrms   0.069721   0.013344 -0.046701
# ...

# %%
fig=plt.figure(figsize=(16,16))
fig.add_subplot(1,1,1)
sns.heatmap(cf.corr(),annot=True,annot_kws={'size':12},cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
def getcorrelatedfeature(corrdata,threshold):
    feature=[]
    value=[]
    for i, index in enumerate(corrdata.index):
        if abs(corrdata[index])>threshold:
            feature.append(index)
            value.append(corrdata[index])
    df=pd.DataFrame(data=value,index=feature,columns=['corr_value'])
    return df

# %%
threshold=0.1
corr_value=getcorrelatedfeature(cormat['Price'],threshold)
corr_value
# Out:
#           corr_value
# MedInc      0.688075
# HouseAge    0.105623
# AveRooms    0.151948
# Latitude   -0.144160
# Price       1.000000

# %%
correlated_data=cf[corr_value.index]
correlated_data.head()
# Out:
#    MedInc  HouseAge  AveRooms  Latitude  Price
# 0  8.3252      41.0  6.984127     37.88  4.526
# 1  8.3014      21.0  6.238137     37.86  3.585
# 2  7.2574      52.0  8.288136     37.85  3.521
# 3  5.6431      52.0  5.817352     37.85  3.413
# 4  3.8462      52.0  6.281853     37.85  3.422

# %%
sns.pairplot(correlated_data)
plt.show()

# %%
sns.heatmap(correlated_data.corr(),annot=True)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x=correlated_data.drop(['Price', 'Latitude'],axis=1)
y=correlated_data['Price']

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.2,
                                   random_state=42)

# %%
X_train.shape,X_test.shape,Y_train.shape,Y_test.shape
# Out:
# ((16512, 3), (4128, 3), (16512,), (4128,))

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred=model.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.metrics import r2_score, mean_absolute_error

# %%
score=r2_score(Y_test,Y_pred)
mse=mean_squared_error(Y_test,Y_pred)
mae=mean_absolute_error(Y_test,Y_pred)
print("r2 score is: ",score)
print("mse is: ",mse)
print("mae is: ",mae)
# Out:
# r2 score is:  0.49717158850807075
# mse is:  0.6589108649336336
# mae is:  0.6033213567335047

# %%
import pickle

# %%
with open('b_model' , 'ab') as f:
    pickle.dump(model,f)

# %%
from flask import Flask, request, render_template

# %%
import joblib

# %%
app=Flask(__name__)
model=joblib.load('b_model')

@app.route('/')
def hello(name=None):
    return render_template('index.html',name=name)
@app.route('/results',methods=["GET","POST"])
def get_value():
    if request.method=="POST":
        rm=float(request.form.get('MedInc'))
        pt=float(request.form.get('HouseAge'))
        lstat=float(request.form.get('AveRooms'))
        pred=model.predict([[rm,pt,lstat]])
        return render_template('results.html',prediction=pred)

# %%
if __name__=="__main__":
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)

# %%
min_value = df['MedInc'].min()
max_value = df['MedInc'].max()
range_value = max_value - min_value

print(f"Minimum: {min_value}, Maximum: {max_value}, Range: {range_value}")

# %%
min_value = df['HouseAge'].min()
max_value = df['HouseAge'].max()
range_value = max_value - min_value

print(f"Minimum: {min_value}, Maximum: {max_value}, Range: {range_value}")

# %%
min_value = df['AveRooms'].min()
max_value = df['AveRooms'].max()
range_value = max_value - min_value

print(f"Minimum: {min_value}, Maximum: {max_value}, Range: {range_value}")
